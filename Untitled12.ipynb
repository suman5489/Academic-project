# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %%
df=pd.read_excel("/content/jilla.xlsx")
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
print('Number of examples and features:',df.shape)
print('features in the dataset:',df.columns.tolist())
# Out:
# Number of examples and features: (1000, 10)
# features in the dataset: ['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country', 'Timestamp', 'Clicked on Ad']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   datetime64[ns]
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(3)
# memory usage: 78.2+ KB

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
fig=plt.figure(figsize=(7,7))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
fig=plt.figure(figure=(7,6))
sns.countplot(x='Clicked on Ad',data=df)
print(df['Clicked on Ad'].value_counts())
# Out:
# 0    500
# 1    500
# Name: Clicked on Ad, dtype: int64

# %%
fig=plt.figure(figsize=(7,6))
sns.countplot(x='Male',data=df)
print(df['Male'].value_counts())
# Out:
# 0    519
# 1    481
# Name: Male, dtype: int64

# %%
df.hist(['Daily Internet Usage', 'Daily Time Spent on Site', 'Age','Area Income'],figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Daily Internet Usage'}>,
#         <Axes: title={'center': 'Daily Time Spent on Site'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Area Income'}>]], dtype=object)

# %%
sns.scatterplot(x='Age',y='Daily Internet Usage', hue='Clicked on Ad',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Daily Internet Usage'>

# %%
sns.scatterplot(x='Area Income',y='Daily Time Spent on Site', hue='Clicked on Ad',data=df)
# Out:
# <Axes: xlabel='Area Income', ylabel='Daily Time Spent on Site'>

# %%
sns.jointplot(x='Daily Internet Usage', y='Daily Time Spent on Site',data=df,hue='Clicked on Ad',palette='dark')

# %%
fig=plt.figure(figsize=(7,6))
sns.violinplot(x='Clicked on Ad',y='Age',data=df)
# Out:
# <Axes: xlabel='Clicked on Ad', ylabel='Age'>

# %%
continuouscolslist=['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage']

# %%
import matplotlib.pyplot as plt

fig, PlotCanvas = plt.subplots(nrows=1, ncols=len(continuouscolslist), figsize=(18,5))

for PredictorCal, i in zip(continuouscolslist, range(len(continuouscolslist))):
    df.boxplot(column=PredictorCal, by='Clicked on Ad', figsize=(5,5), vert=True, ax=PlotCanvas[i])

# %%
fig=plt.figure(figsize=(7,6))
sns.boxplot(x='Clicked on Ad',y='Area Income',data=df)
# Out:
# <Axes: xlabel='Clicked on Ad', ylabel='Area Income'>

# %%
fig=plt.figure(figsize=(7,6))
sns.boxplot(x='Clicked on Ad',y='Area Income',data=df)
# Out:
# <Axes: xlabel='Clicked on Ad', ylabel='Area Income'>

# %%
sns.lmplot(x='Daily Time Spent on Site',y='Daily Internet Usage',data=df,fit_reg=False,hue='Clicked on Ad')

# %%
fig=plt.figure(figsize=(7,6))
sns.swarmplot(x='Clicked on Ad',y='Daily Internet Usage',data=df)
# Out:
# <Axes: xlabel='Clicked on Ad', ylabel='Daily Internet Usage'>

# %%
crosstab=pd.crosstab(index=df['Male'],columns=df['Clicked on Ad'])
crosstab
# Out:
# Clicked on Ad    0    1
# Male
# 0              250  269
# 1              250  231

# %%
pd.crosstab(index=df['Country'],columns='Count').sort_values(['Count'],ascending=False).head(10)
# Out:
# col_0           Count
# Country
# France              9
# Czech Republic      9
# Afghanistan         8
# Australia           8
# Turkey              8
# South Africa        8
# Senegal             8
# Peru                8
# Micronesia          8
# Greece              8

# %%
pd.crosstab(index=df['City'],columns='Count').sort_values(['Count'],ascending=False).head(10)
# Out:
# col_0            Count
# City
# Lisamouth            3
# Williamsport         3
# Johnstad             2
# New Sheila           2
# Benjaminchester      2
# Millerbury           2
# Michelleside         2
# West Steven          2
# Lake Jose            2
# West Shannon         2

# %%
sns.pairplot(df,hue='Clicked on Ad',vars=['Daily Time Spent on Site','Daily Internet Usage','Age','Area Income' ],palette='dark')

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])
df['Month']=df['Timestamp'].dt.month
df['Day of month']=df['Timestamp'].dt.day
df['Day of the week']=df['Timestamp'].dt.dayofweek
df['Hour']=df['Timestamp'].dt.hour
df=df.drop(['Timestamp'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timestamp'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     43.70   28     63126.96                168.34
# 996                     72.97   30     71384.57                168.41
# 997                     51.30   45     67782.17                168.92
# 998                     51.63   51     42415.72                169.18
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
fig=plt.figure(figsize=(7,6))
sns.countplot(x='Month',hue='Clicked on Ad',data=df)
print(df['Month'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-857b541ad232> in <cell line: 1>()
# ----> 1 sns.countplot(x='Month',hue='Clicked on Ad',data=df)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %%
fig=plt.figure(figsize=(7,6))
sns.countplot(x='Day of the week',data=df)
print(df['Day of the week'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-8f421a330284> in <cell line: 1>()
# ----> 1 sns.countplot(x='Day of the week',data=df)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
# ...

# %%
CrossTabResult=pd.crosstab(index=df['Male'], columns=df['Clicked on Ad'])
CrossTabResult
# Out:
# Clicked on Ad    0    1
# Male
# 0              250  269
# 1              250  231

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of categorical columns
CategoricalColsList = ['Male', 'City', 'Country']

# Create a figure with subplots for each categorical variable
fig, PlotCanvas = plt.subplots(nrows=len(CategoricalColsList), ncols=1, figsize=(15,60 ))

# Creating Grouped bar plots for each categorical predictor against the Target Variable "Clicked"
for CategoricalCol , i in zip(CategoricalColsList, range(len(CategoricalColsList))):
    CrossTabResult=pd.crosstab(index=df[CategoricalCol], columns=df['Clicked on Ad'])
    CrossTabResult.plot(kind="bar", figsize=(10,5), stacked=True, ax=PlotCanvas[i])
    PlotCanvas[i].set_xlabel(CategoricalCol,fontsize=12)
    PlotCanvas[i].set_title('Clicked on Ad' + ' vs ' + CategoricalCol, fontsize=2)

# %%
fig=plt.figure(figsize=(7,6))
sns.countplot(x='Day of month',data=df)
print(df['Day of month'].value_counts())
# Out:
# 3     46
# 17    42
# 15    41
# 10    37
# 26    36
# 4     36
# 16    35
# 23    35
# 5     35
# 27    35
# 8     35
# 18    35
# 9     34
# 20    33
# 1     33
# 24    33
# 14    33
# 11    32
# 7     32
# 21    32
# 28    30
# 13    30
# 29    29
# 12    29
# 19    29
# 30    28
# 6     25
# 2     25
# 22    24
# 25    23
# 31    18
# Name: Day of month, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
X = df.drop(labels=['Ad Topic Line','City','Country','Timestamp','Clicked on Ad'], axis=1)
y = df['Clicked on Ad']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (700, 5)
# (700,)
# (300, 5)
# (300,)

# %%
lr_model = LogisticRegression(solver='lbfgs', max_iter=1000)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lr_predict = lr_model.predict(X_test)

# %%
print(classification_report(y_test, lr_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90       146
#            1       0.96      0.84      0.89       154
#
#     accuracy                           0.90       300
#    macro avg       0.90      0.90      0.90       300
# weighted avg       0.90      0.90      0.90       300

# %%
print(accuracy_score(lr_predict, y_test)*100)
# Out:
# 89.66666666666666

# %%
from sklearn.metrics import confusion_matrix
accuracy=confusion_matrix(lr_predict, y_test)
accuracy
# Out:
# array([[140,  25],
#        [  6, 129]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...
